# %% [markdown]
# # WINE QUALITY ANALYSIS

# %% [markdown]
# # IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
wine_df = pd.read_csv('1613779-Red_wine_.csv')
wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4      5.0
# 1      9.8      5.0
# 2      9.8      5.0
# ...

# %% [markdown]
# ####  Exploring Data

# %%
# cheak the number of rows and columns in Pandas Dataframe : wine_df
wine_df.shape
# Out:
# (1599, 12)

# %%
# cheak the row index labels of Pandas Dataframe
wine_df.index
# Out:
# RangeIndex(start=0, stop=1599, step=1)

# %%
#cheak the column labels of Pandas Dataframe
wine_df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
# Get the consice summary of Dataframe:wine_df
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1598 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1598 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
# finding missing values using isna() and any() in columns of the DataFrame: wine_df
wine_df.isna().any()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide     True
# density                 False
# pH                       True
# sulphates               False
# alcohol                 False
# quality                  True
# dtype: bool

# %%
# finding the number of missing values in each of the columns of the DataFrame: wine_df
wine_df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    1
# density                 0
# pH                      1
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %%
wine_df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1598.000000  1599.000000
# mean      0.087467            15.874922             46.433041     0.996747
# std       0.047065            10.460157             32.876249     0.001887
# ...

# %%
# finding the rows where missing values are present
wine_df[wine_df['total sulfur dioxide'].isna()]
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 9            7.5               0.5         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 9                 17.0                   NaN   0.9978  3.35        0.8
#
#    alcohol  quality
# 9     10.5      5.0

# %%
wine_df[wine_df['pH'].isna()]
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 184            6.7              0.62         0.21             1.9      0.079
#
#      free sulfur dioxide  total sulfur dioxide  density  pH  sulphates  \
# 184                  8.0                  62.0    0.997 NaN       0.58
#
#      alcohol  quality
# 184      9.3      6.0

# %%
wine_df[wine_df['quality'].isna()]
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 123            8.0              0.71          0.0             2.6       0.08
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 123                 11.0                  34.0   0.9976  3.44       0.53
#
#      alcohol  quality
# 123      9.5      NaN

# %%
wine_df = wine_df.dropna()

# %%
wine_df.isna().any()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# dtype: bool

# %% [markdown]
# ### Handling duplicates

# %%
# find the number of duplicate records the DataFrame: cars_df
wine_df.duplicated().sum()
# Out:
# 239

# %%
# get the duplicate records in the DataFrame: cars_df
wine_df[wine_df.duplicated()]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.4             0.700         0.00            1.90      0.076
# 27              7.9             0.430         0.21            1.60      0.106
# 40              7.3             0.450         0.36            5.90      0.074
# 65              7.2             0.725         0.05            4.65      0.086
# 76              8.8             0.410         0.64            2.20      0.093
# ...             ...               ...          ...             ...        ...
# 1563            7.2             0.695         0.13            2.00      0.076
# 1564            7.2             0.695         0.13            2.00      0.076
# 1567            7.2             0.695         0.13            2.00      0.076
# 1581            6.2             0.560         0.09            1.70      0.053
# 1596            6.3             0.510         0.13            2.30      0.076
#
# ...

# %%
# dropping the duplicate records in the DataFrame: wine_df
wine_df.drop_duplicates(inplace=True)
wine_df.duplicated().sum()
# Out:
# C:\Users\Riya Tyagi\AppData\Local\Temp\ipykernel_10316\1957437698.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wine_df.drop_duplicates(inplace=True)
# 0

# %% [markdown]
# ### Checking column datatypes

# %%
# get the data types of all columns of the DataFrame: cars_df
wine_df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                 float64
# dtype: object

# %%
wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# ### Boxplot

# %%
plt.subplot(4,3,1)
wine_df['fixed acidity'].plot(kind='box') 
plt.subplot(4,3,2)
wine_df['volatile acidity'].plot(kind='box') 
plt.subplot(4,3,3)
wine_df['citric acid'].plot(kind='box') 
plt.subplot(4,3,4)
wine_df['residual sugar'].plot(kind='box') 
plt.subplot(4,3,5)
wine_df['chlorides'].plot(kind='box') 
plt.subplot(4,3,6)
wine_df['free sulfur dioxide'].plot(kind='box') 
plt.subplot(4,3,7)
wine_df['total sulfur dioxide'].plot(kind='box') 
plt.subplot(4,3,8)
wine_df['density'].plot(kind='box') 
plt.subplot(4,3,9)
wine_df['pH'].plot(kind='box') 
plt.subplot(4,3,10)
wine_df['sulphates'].plot(kind='box') 
plt.subplot(4,3,11)
wine_df['alcohol'].plot(kind='box') 
plt.subplot(4,3,12)
wine_df['quality'].plot(kind='box') 
plt.tight_layout()

# %%
wine_df[['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','quality']].describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1357.000000       1357.000000  1357.000000     1357.000000
# mean        8.312012          0.529278     0.272579        2.523803
# std         1.737699          0.183084     0.195533        1.353203
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.430000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1357.000000          1357.000000           1357.000000  1357.000000
# mean      0.088136            15.902727             46.824245     0.996708
# std       0.049412            10.451925             33.429220     0.001870
# ...

# %%
# finding the upper and lower limit of horespower and acceleration columns

def find_outlier_limits(col_name):
    Q1,Q3=wine_df[col_name].quantile([.25,.75])
    IQR=Q3-Q1
    low=Q1-(1.5* IQR)
    high=Q3+(1.5* IQR)
    return (high,low)

high_fix,low_fix=find_outlier_limits('fixed acidity')
print('fixed acidity: ','upper limit: ',high_fix,' lower limit: ',low_fix)
high_va,low_va=find_outlier_limits('volatile acidity')
print('volatile acidity: ','upper limit: ',high_va,' lower limit:',low_va)
high_ca,low_ca=find_outlier_limits('citric acid')
print('citric acid: ','upper limit: ',high_ca,' lower limit: ',low_ca)
high_rs,low_rs=find_outlier_limits('residual sugar')
print('residual sugar: ','upper limit: ',high_rs,' lower limit: ',low_rs)
high_chl,low_chl=find_outlier_limits('chlorides')
print('chlorides: ','upper limit: ',high_chl,' lower limit: ',low_chl)
high_fsd,low_fsd=find_outlier_limits('free sulfur dioxide')
print('free sulfur dioxide: ','upper limit: ',high_fsd,' lower limit: ',low_fsd)
high_tsd,low_tsd=find_outlier_limits('total sulfur dioxide')
print('total sulfur dioxide: ','upper limit: ',high_tsd,' lower limit: ',low_tsd)
high_den,low_den=find_outlier_limits('density')
print('density: ','upper limit: ',high_den,' lower limit: ',low_den)
high_pH,low_pH=find_outlier_limits('pH')
print('pH: ','upper limit: ',high_pH,' lower limit: ',low_pH)
high_sulp,low_sulp=find_outlier_limits('sulphates')
print('sulphates: ','upper limit: ',high_sulp,' lower limit: ',low_sulp)
high_alc,low_alc=find_outlier_limits('alcohol')
print('alcohol: ','upper limit: ',high_alc,' lower limit: ',low_alc)
high_qu,low_qu=find_outlier_limits('quality')
print('quality: ','upper limit: ',high_qu,' lower limit: ',low_qu)


# Replacing outlier values in horespower and acceleration columns with respective 
# upper and lower limits

wine_df.loc[wine_df['fixed acidity']>high_fix,'fixed acidity']=high_fix
wine_df.loc[wine_df['volatile acidity']>high_va,'volatile acidity']=high_va
wine_df.loc[wine_df['citric acid']>high_ca,'citric acid']=high_ca
wine_df.loc[wine_df['residual sugar']>high_rs,'residual sugar']=high_rs
wine_df.loc[wine_df['residual sugar']<low_rs,'residual sugar']=low_rs
wine_df.loc[wine_df['chlorides']>high_chl,'chlorides']=high_chl
wine_df.loc[wine_df['chlorides']<low_chl,'chlorides']=low_chl
wine_df.loc[wine_df['free sulfur dioxide']>high_fsd,'free sulfur dioxide']=high_fsd
wine_df.loc[wine_df['total sulfur dioxide']>high_tsd,'total sulfur dioxide']=high_tsd
wine_df.loc[wine_df['density']>high_den,'density']=high_den
wine_df.loc[wine_df['density']<low_den,'density']=low_den
wine_df.loc[wine_df['pH']>high_pH,'pH']=high_pH
wine_df.loc[wine_df['sulphates']>high_sulp,'sulphates']=high_sulp
wine_df.loc[wine_df['alcohol']>high_alc,'alcohol']=high_alc
wine_df.loc[wine_df['quality']>high_qu,'quality']=high_qu
wine_df.loc[wine_df['quality']<low_qu,'quality']=low_qu
# Out:
# fixed acidity:  upper limit:  12.349999999999998  lower limit:  3.95
# volatile acidity:  upper limit:  1.0150000000000001  lower limit: 0.015000000000000013
# citric acid:  upper limit:  0.94  lower limit:  -0.42000000000000004
# residual sugar:  upper limit:  3.6500000000000004  lower limit:  0.8499999999999996
# chlorides:  upper limit:  0.12249999999999998  lower limit:  0.03850000000000002
# free sulfur dioxide:  upper limit:  42.0  lower limit:  -14.0
# total sulfur dioxide:  upper limit:  124.5  lower limit:  -39.5
# density:  upper limit:  1.00115  lower limit:  0.99227
# pH:  upper limit:  3.52  lower limit:  3.52
# sulphates:  upper limit:  0.9999999999999999  lower limit:  0.28000000000000014
# alcohol:  upper limit:  13.5  lower limit:  7.1000000000000005
# quality:  upper limit:  7.5  lower limit:  3.5
# C:\Users\Riya Tyagi\AppData\Local\Temp\ipykernel_10316\705100884.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
plt.subplot(4,3,1)
wine_df['fixed acidity'].plot(kind='box') 
plt.subplot(4,3,2)
wine_df['volatile acidity'].plot(kind='box') 
plt.subplot(4,3,3)
wine_df['citric acid'].plot(kind='box') 
plt.subplot(4,3,4)
wine_df['residual sugar'].plot(kind='box') 
plt.subplot(4,3,5)
wine_df['chlorides'].plot(kind='box') 
plt.subplot(4,3,6)
wine_df['free sulfur dioxide'].plot(kind='box') 
plt.subplot(4,3,7)
wine_df['total sulfur dioxide'].plot(kind='box') 
plt.subplot(4,3,8)
wine_df['density'].plot(kind='box') 
plt.subplot(4,3,9)
wine_df['pH'].plot(kind='box') 
plt.subplot(4,3,10)
wine_df['sulphates'].plot(kind='box') 
plt.subplot(4,3,11)
wine_df['alcohol'].plot(kind='box') 
plt.subplot(4,3,12)
wine_df['quality'].plot(kind='box') 
plt.tight_layout()

# %%
wine_df['quality'].value_counts()
# Out:
# 5.0    576
# 6.0    534
# 7.0    167
# 4.0     53
# 7.5     17
# 3.5     10
# Name: quality, dtype: int64

# %% [markdown]
# #### Data Visualisation

# %%
# checking the variation of fixed acidity in the different qualities of wine

plt.scatter(wine_df['quality'], wine_df['fixed acidity'], color = 'red')
plt.title('relation of fixed acidity with wine')
plt.xlabel('quality')
plt.ylabel('fixed acidity')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# checking the variation of fixed acidity in the different qualities of wine

plt.bar(wine_df['quality'], wine_df['alcohol'], color = 'blue')
plt.title('relation of alcohol with wine')
plt.xlabel('quality')
plt.ylabel('alcohol')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Composition of citric acid go higher as we go higher in the quality of the wine

import seaborn as sns

fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'citric acid', data = wine_df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='citric acid'>

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'residual sugar', data = wine_df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='residual sugar'>

# %%
#Composition of chloride also go down as we go higher in the quality of the wine

fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'chlorides', data = wine_df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='chlorides'>

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'free sulfur dioxide', data = wine_df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='free sulfur dioxide'>

# %%
#Sulphates level goes higher with the quality of wine

fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'sulphates', data = wine_df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='sulphates'>

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'density', data = wine_df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='density'>

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'volatile acidity', data = wine_df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='volatile acidity'>

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'fixed acidity', data = wine_df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='fixed acidity'>

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'total sulfur dioxide', data = wine_df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='total sulfur dioxide'>

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'pH', data = wine_df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='pH'>

# %%
f, ax = plt.subplots(figsize=(10, 8))
corr = wine_df.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)
# Out:
# C:\Users\Riya Tyagi\AppData\Local\Temp\ipykernel_10316\2110422662.py:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
# <AxesSubplot:>

# %%
sns.pairplot(wine_df)

# %%
# Removing Unnecassary columns from the dataset
# As we saw that volatile acidity, total sulphor dioxide, chlorides, density are very less related to the dependent variable 
#   quality so even if we remove these columns the accuracy won't be affected that much.

#wine_df = wine_df.drop(['volatile acidity', 'total sulfur dioxide', 'chlorides', 'density'], axis = 1)

# checking the shape of the dataset
#print(wine_df.shape)

# %%
wine_df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
# converting the response variables(3-7) as binary response variables that is either good or bad

names = ['bad', 'good']
#bins = (2, 6.5, 8)

#wine_df['quality'] = pd.cut(wine_df['quality'], bins = bins, labels = names)

wine_df['quality'] = wine_df['quality'].map({3 : 'bad', 4 :'bad', 5: 'bad',
                                      6: 'good', 7: 'good', 8: 'good'})
# Out:
# C:\Users\Riya Tyagi\AppData\Local\Temp\ipykernel_10316\2632717860.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wine_df['quality'] = wine_df['quality'].map({3 : 'bad', 4 :'bad', 5: 'bad',

# %%
# analyzing the different values present in the dependent variable(quality column)
wine_df['quality'].value_counts()
# Out:
# good    701
# bad     629
# Name: quality, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

wine_df['quality'] = le.fit_transform(wine_df['quality'])

wine_df['quality'].value_counts
# Out:
# C:\Users\Riya Tyagi\AppData\Local\Temp\ipykernel_10316\4200608822.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wine_df['quality'] = le.fit_transform(wine_df['quality'])
# <bound method IndexOpsMixin.value_counts of 0       0
# 1       0
# 2       0
# 3       1
# 5       0
#        ..
# 1593    1
# 1594    0
# 1595    1
# 1597    0
# 1598    1
# Name: quality, Length: 1357, dtype: int32>

# %%
sns.countplot(wine_df['quality'])
# Out:
# C:\Users\Riya Tyagi\anaconda set up\New folder\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
# dividing the dataset into dependent and independent variables

x = wine_df.iloc[:,:11]
y = wine_df.iloc[:,11]

# determining the shape of x and y.
print(x.shape)
print(y.shape)
# Out:
# (1357, 11)
# (1357,)

# %%
# dividing the dataset in training and testing set

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 44)

# determining the shapes of training and testing sets
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (1017, 11)
# (1017,)
# (340, 11)
# (340,)

# %%
# standard scaling 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %% [markdown]
# ### Modelling

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

from sklearn.model_selection import GridSearchCV, cross_val_score



# creating the model
model = LogisticRegression()

# feeding the training set into the model
model.fit(x_train, y_train)

# predicting the results for the test set
y_pred = model.predict(x_test)

# calculating the training and testing accuracies
print("Training accuracy :", model.score(x_train, y_train))
print("Testing accuracy :", model.score(x_test, y_test))

# classification report
print(classification_report(y_test, y_pred))

# confusion matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# Training accuracy : 0.727630285152409
# Testing accuracy : 0.7264705882352941
#               precision    recall  f1-score   support
#
#            0       0.72      0.73      0.72       155
#            1       0.73      0.77      0.75       174
#            2       0.00      0.00      0.00        11
#
#     accuracy                           0.73       340
#    macro avg       0.48      0.50      0.49       340
# weighted avg       0.70      0.73      0.71       340
#
# [[113  42   0]
#  [ 40 134   0]
#  [  4   7   0]]
# C:\Users\Riya Tyagi\anaconda set up\New folder\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
# code
x_pred = list(model.predict(x_test))
df = {'predicted':x_pred,'original':y_test}
pd.DataFrame(df).head(10)
# Out:
#       predicted  original
# 1360          0         0
# 859           1         1
# 954           1         1
# 1202          1         2
# 1555          1         1
# 1443          1         0
# 1046          1         1
# 1497          1         1
# 507           0         1
# 460           1         1

# %% [markdown]
# ### Stochastic Gradient Descent Classifier

# %%
from sklearn.linear_model import SGDClassifier

# creating the model
model2 = SGDClassifier(penalty=None)

# feeding the training model into the model
model2.fit(x_train, y_train)

# predicting the values for the test set
y_pred = model2.predict(x_test)

# classification report
print(classification_report(y_test, y_pred))

# calculating the training and testing accuracies
print("Training accuracy :", model2.score(x_train, y_train))
print("Testing accuracy :", model2.score(x_test, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.68      0.67       155
#            1       0.69      0.71      0.70       174
#            2       0.00      0.00      0.00        11
#
#     accuracy                           0.67       340
#    macro avg       0.45      0.46      0.46       340
# weighted avg       0.65      0.67      0.66       340
#
# Training accuracy : 0.7010816125860374
# Testing accuracy : 0.6735294117647059
# C:\Users\Riya Tyagi\anaconda set up\New folder\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
# code
x_pred = list(model2.predict(x_test))
df = {'predicted':x_pred,'original':y_test}
pd.DataFrame(df).head(10)
# Out:
#       predicted  original
# 1360          0         0
# 859           1         1
# 954           1         1
# 1202          1         2
# 1555          1         1
# 1443          1         0
# 1046          1         1
# 1497          1         1
# 507           0         1
# 460           1         1

# %% [markdown]
# ### Support Vector Machine

# %%
from sklearn.svm import SVC

# creating the model
model3 = SVC()

# feeding the training set into the model
model3.fit(x_train, y_train)

# predicting the results for the test set
y_pred = model3.predict(x_test)

# calculating the training and testing accuracies
print("Training accuracy :", model3.score(x_train, y_train))
print("Testing accuracy :", model3.score(x_test, y_test))
# Out:
# Training accuracy : 0.783677482792527
# Testing accuracy : 0.7

# %%
# finding the best parameters for the SVC model

param = {
    'C': [0.8,0.9,1,1.1,1.2,1.3,1.4],
    'kernel':['linear', 'rbf'],
    'gamma' :[0.1,0.8,0.9,1,1.1,1.2,1.3,1.4]
}
grid_svc = GridSearchCV(model3, param_grid = param, scoring = 'accuracy', cv = 10)

# %%
grid_svc.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=SVC(),
#              param_grid={'C': [0.8, 0.9, 1, 1.1, 1.2, 1.3, 1.4],
#                          'gamma': [0.1, 0.8, 0.9, 1, 1.1, 1.2, 1.3, 1.4],
#                          'kernel': ['linear', 'rbf']},
#              scoring='accuracy')

# %%
grid_svc.best_params_
# Out:
# {'C': 1.4, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
# creating a new SVC model with these best parameters

model4 = SVC(C = 1.4, gamma = 0.1, kernel = 'rbf')
model4.fit(x_train, y_train)
y_pred = model4.predict(x_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.74      0.71       155
#            1       0.73      0.74      0.73       174
#            2       0.00      0.00      0.00        11
#
#     accuracy                           0.71       340
#    macro avg       0.47      0.49      0.48       340
# weighted avg       0.69      0.71      0.70       340
# C:\Users\Riya Tyagi\anaconda set up\New folder\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
# code
x_pred = list(model4.predict(x_test))
df = {'predicted':x_pred,'original':y_test}
pd.DataFrame(df).head(10)
# Out:
#       predicted  original
# 1360          1         0
# 859           1         1
# 954           1         1
# 1202          1         2
# 1555          1         1
# 1443          1         0
# 1046          0         1
# 1497          1         1
# 507           1         1
# 460           1         1

# %% [markdown]
# ### Decision Forest

# %%
from sklearn.tree import DecisionTreeClassifier

# creating model
model5 = DecisionTreeClassifier()

# feeding the training set into the model
model5.fit(x_train, y_train)

# predicting the results for the test set
y_pred = model5.predict(x_test)

# calculating the training and testing accuracies
print("Training accuracy :", model5.score(x_train, y_train))
print("Testing accuracy :", model5.score(x_test, y_test))
# Out:
# Training accuracy : 1.0
# Testing accuracy : 0.6264705882352941

# %%
# classification report
print(classification_report(y_test, y_pred))

# confusion matrix
print(confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.60      0.62       155
#            1       0.62      0.69      0.66       174
#            2       0.00      0.00      0.00        11
#
#     accuracy                           0.63       340
#    macro avg       0.42      0.43      0.42       340
# weighted avg       0.61      0.63      0.62       340
#
# [[ 93  62   0]
#  [ 52 120   2]
#  [  1  10   0]]

# %%
#Now lets try to do some evaluation for decision tree model using cross validation.

model_eval = cross_val_score(estimator = model5, X = x_train, y = y_train, cv = 10)
model_eval.mean()
# Out:
# 0.6410794020578527

# %%
# code
x_pred = list(model5.predict(x_test))
df = {'predicted':x_pred,'original':y_test}
pd.DataFrame(df).head(10)
# Out:
#       predicted  original
# 1360          1         0
# 859           1         1
# 954           1         1
# 1202          1         2
# 1555          0         1
# 1443          1         0
# 1046          0         1
# 1497          1         1
# 507           1         1
# 460           1         1

# %% [markdown]
# ### Multi layer Perceptron

# %%
from sklearn.neural_network import MLPClassifier

# creating the model
model6 = MLPClassifier(hidden_layer_sizes = (100, 100), max_iter = 150)

# feeding the training data to the model
model6.fit(x_train, y_train)

# calculating the accuracies
print("training accuracy :", model6.score(x_train, y_train))
print("testing accuracy :", model6.score(x_test, y_test))
# Out:
# training accuracy : 0.8997050147492626
# testing accuracy : 0.7
# C:\Users\Riya Tyagi\anaconda set up\New folder\anaconda\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (150) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
# code
x_pred = list(model6.predict(x_test))
df = {'predicted':x_pred,'original':y_test}
pd.DataFrame(df).head(10)
# Out:
#       predicted  original
# 1360          0         0
# 859           1         1
# 954           1         1
# 1202          1         2
# 1555          1         1
# 1443          0         0
# 1046          0         1
# 1497          1         1
# 507           1         1
# 460           1         1

# %% [markdown]
# ### Random Forest Classifier

# %%
# code
#import libraries
from sklearn.ensemble import RandomForestClassifier

# for error checking
from sklearn.metrics import mean_squared_error

from sklearn.metrics import classification_report

# create model variable
rnd = RandomForestClassifier()

# fit the model
fit_rnd = rnd.fit(x_train,y_train)

# checking the accuracy score
rnd_score = rnd.score(x_test,y_test)

print('score of model is : ',rnd_score)

print('.................................')

print('calculating the error')

# checking mean_squared error
MSE = mean_squared_error(y_test,y_pred)

# checking root mean squared error
RMSE = np.sqrt(MSE)

print('mean squared error is : ',MSE)

print('root mean squared error is : ',RMSE)

print(classification_report(y_test,y_pred))
# Out:
# score of model is :  0.711764705882353
# .................................
# calculating the error
# mean squared error is :  0.38235294117647056
# root mean squared error is :  0.6183469424008423
#               precision    recall  f1-score   support
#
#            0       0.64      0.60      0.62       155
#            1       0.62      0.69      0.66       174
#            2       0.00      0.00      0.00        11
#
#     accuracy                           0.63       340
#    macro avg       0.42      0.43      0.42       340
# weighted avg       0.61      0.63      0.62       340

# %%
# code
x_pred = list(rnd.predict(x_test))
df = {'predicted':x_pred,'original':y_test}
pd.DataFrame(df).head(10)
# Out:
#       predicted  original
# 1360          0         0
# 859           1         1
# 954           1         1
# 1202          1         2
# 1555          1         1
# 1443          0         0
# 1046          1         1
# 1497          1         1
# 507           1         1
# 460           1         1
